# %%
a = 42
b = 'universe'
print(f'The answer to life, the {b}, and everything is: {a:.2f}')
# Out:
# The answer to life, the universe, and everything is: 42.00

# %%
a = range(10)
a2 = [x**2 for x in a]
print(a)
print(a2)
# Out:
# range(0, 10)
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
